# %% [markdown]
# <a href="https://colab.research.google.com/github/mfernandezzz/Data-Analysis-Projects/blob/main/demographic_data_analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Demographic Data Analyzer**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/adult.csv')
df.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
nulls_count = df.isnull().sum()
nulls_count[nulls_count > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
df.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %% [markdown]
# Assign name columns to the dataset

# %%
col_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain',
             'capital-loss', 'hours-per-week', 'native-country', 'salary']

df.columns = col_names
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0             0             0              13   United-States   <=50K
# ...

# %% [markdown]
# The previous names of columns correspond to a row of data that was missing

# %%
mask = (df['workclass'].str.contains('State-gov')) & (df['fnlwgt'] == 77516)
df.loc[mask]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# Add the missing row of data to the DataFrame

# %%
missed_row = {'age': 39, 'workclass': 'State-gov', 'fnlwgt': 77516, 'education': 'Bachelors', 'education-num': 13, 'marital-status': 'Never-married',
       'occupation': 'Adm-clerical', 'relationship': 'Not-in-family', 'race': 'White', 'sex': 'Male', 'capital-gain': 2174, 'capital-loss': 0,
       'hours-per-week': 40, 'native-country': 'United-States', 'salary': '<=50K'}
df = pd.concat([df, pd.DataFrame([missed_row])], ignore_index=True)

# %%
# to add multiple rows
# rows = [
#     {"col1": 10, "col2": "abc"},
#     {"col1": 20, "col2": "def"},
# ]
# df = pd.concat([df, pd.DataFrame(rows)], ignore_index=True)

# %%
mask = (df['workclass'].str.contains('State-gov')) & (df['fnlwgt'] == 77516)
df.loc[mask]
# Out:
#        age  workclass  fnlwgt  education  education-num marital-status  \
# 32560   39  State-gov   77516  Bachelors             13  Never-married
#
#          occupation   relationship   race   sex  capital-gain  capital-loss  \
# 32560  Adm-clerical  Not-in-family  White  Male          2174             0
#
#        hours-per-week native-country salary
# 32560              40  United-States  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th', 'Bachelors'], dtype=object)

# %%
columns_strings = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'salary']
for col in columns_strings:
  df[col] = df[col].astype(str).str.strip()

# %%
df['education'].unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
mask_dupples = df.duplicated()
show_duplicated = df.loc[mask_dupples]
show_duplicated.head()
# Out:
#        age workclass  fnlwgt     education  education-num marital-status  \
# 4880    25   Private  308144     Bachelors             13  Never-married
# 5103    90   Private   52386  Some-college             10  Never-married
# 9170    21   Private  250051  Some-college             10  Never-married
# 11630   20   Private  107658  Some-college             10  Never-married
# 13083   25   Private  195994       1st-4th              2  Never-married
#
#             occupation   relationship                race     sex  \
# 4880      Craft-repair  Not-in-family               White    Male
# 5103     Other-service  Not-in-family  Asian-Pac-Islander    Male
# 9170    Prof-specialty      Own-child               White  Female
# 11630     Tech-support  Not-in-family               White  Female
# 13083  Priv-house-serv  Not-in-family               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (32537, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %% [markdown]
# **How many people of each race are represented in this dataset? Create a DataFrame with race names, quantity and percentage of people per race.**

# %%
df_race_people = pd.DataFrame(df['race'].value_counts()).reset_index()
df_race_people.rename(columns={'count': 'individuals'}, inplace=True)
df_race_people['%'] = round((df_race_people['individuals'] / df_race_people['individuals'].sum()) * 100, 2)
df_race_people
# Out:
#                  race  individuals      %
# 0               White        27795  85.43
# 1               Black         3122   9.60
# 2  Asian-Pac-Islander         1038   3.19
# 3  Amer-Indian-Eskimo          311   0.96
# 4               Other          271   0.83

# %%
race_percentage = pd.DataFrame({
    'race': ['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other'],
    'quantity': [27795, 3122, 1038, 311, 271]
}, columns = ['race', 'quantity'])

race_percentage['%'] = round(race_percentage['quantity'] * 100 / df.shape[0], 2)
race_percentage
# Out:
#                  race  quantity      %
# 0               White     27795  85.43
# 1               Black      3122   9.60
# 2  Asian-Pac-Islander      1038   3.19
# 3  Amer-Indian-Eskimo       311   0.96
# 4               Other       271   0.83

# %%
# race_series = pd.Series(df['race'].value_counts())
# race_series.name = 'Quantity of people by race'
# race_series.index.name = 'Race'
# race_series

# %%
# df_race_people = pd.Series([27815, 3124, 1039, 311, 271])
# df_race_people.index = [
#     'White',
#     'Black',
#     'Asian-Pac-Islander',
#     'Amer-Indian-Eskimo',
#     'Other'
# ]
# df_race_people.name = 'Quantity of people per race'
# df_race_people.index.name = 'Race'
# df_race_people

# %% [markdown]
# **What is the average age of men?**

# %%
average_age_men = df.loc[df['sex'].str.contains('Male'), 'age'].mean()
f'Average age of men: {round(average_age_men)} years old'
# Out:
# 'Average age of men: 39 years old'

# %%
mask_male = df['sex'].str.contains('Male')
df_males = df.loc[mask_male][['age']]

# %%
df_males['age'].median()
# Out:
# 38.0

# %% [markdown]
# **What is the percentage of people who have a Bachelor's degree?**

# %%
df_education = pd.DataFrame(df['education'].value_counts()).reset_index()
df_education.rename(columns={'count': 'individuals'}, inplace=True)
df_education['%'] = round((df_education['individuals'] / df_education['individuals'].sum()) * 100, 2)
df_education
# Out:
#        education  individuals      %
# 0        HS-grad        10494  32.25
# 1   Some-college         7282  22.38
# 2      Bachelors         5353  16.45
# 3        Masters         1722   5.29
# 4      Assoc-voc         1382   4.25
# 5           11th         1175   3.61
# 6     Assoc-acdm         1067   3.28
# 7           10th          933   2.87
# 8        7th-8th          645   1.98
# 9    Prof-school          576   1.77
# 10           9th          514   1.58
# 11          12th          433   1.33
# 12     Doctorate          413   1.27
# 13       5th-6th          332   1.02
# 14       1st-4th          166   0.51
# 15     Preschool           50   0.15

# %%
bachelors_data = df_education.loc[df_education['education'] == 'Bachelors', ['individuals', '%']]
bachelors_data
# Out:
#    individuals      %
# 2         5353  16.45

# %%
print(f'The percentage of people with a Bachelors degree is {bachelors_data.iloc[0, 1]}%')
print(f'The amount of individuals with a Bachelors degree is {bachelors_data.iloc[0, 0]}')
# Out:
# The percentage of people with a Bachelors degree is 16.45%
# The amount of individuals with a Bachelors degree is 5353

# %%
bachelors = df_education.loc[df_education['education'].str.contains('Bachelors'), ['individuals', '%']]
bachelors
# Out:
#    individuals      %
# 2         5353  16.45

# %% [markdown]
# **What percentage of people with advanced education (Bachelors, Masters, Doctorate) make more than 50k?**

# %% [markdown]
# Filter out by education levels and salary level

# %%
mask_adv_ed = ((df['education'] == 'Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate')) & (df['salary'] == '>50K')
df_adv_ed = df.loc[mask_adv_ed]
df_adv_ed.shape
# Out:
# (3486, 15)

# %% [markdown]
# Total of individuals with a salary >50k

# %%
df['salary'].value_counts()
# Out:
# salary
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64

# %%
percentage = (df_adv_ed.shape[0] / 7839) * 100
f'The percentage of people with advanced education and a salary >50k is {round(percentage, 2)}%'
# Out:
# 'The percentage of people with advanced education and a salary >50k is 44.47%'

# %%
# bachelors = df.loc[df['education'].str.contains('Bachelors'), 'salary'].value_counts()
# bachelors

# %% [markdown]
# **What percentage of people without advanced education make more than 50k?**

# %%
low_ed_level = 7839 - df_adv_ed.shape[0]
percentage_two = round((low_ed_level / 7839) * 100, 2)
f'The percentage of people without advanced education and a salary >50k is {percentage_two}%'
# Out:
# 'The percentage of people without advanced education and a salary >50k is 55.53%'

# %% [markdown]
# **What is the minimum and maximum number of hours a person works per week?**

# %%
print(f'The minimum hours a person works per week is {df['hours-per-week'].min()} hours.')
print(f'The maximum hours a person works per week is {df['hours-per-week'].max()} hours.')
# Out:
# The minimum hours a person works per week is 1 hours.
# The maximum hours a person works per week is 99 hours.

# %% [markdown]
# **Obtain the education level and the quantity of individuals who works the minimum and maximum hours per week respectively**

# %%
df.loc[df['hours-per-week'] == 1, 'education'].value_counts()
# Out:
# education
# HS-grad         7
# Assoc-voc       3
# 10th            3
# Some-college    3
# Doctorate       1
# 9th             1
# Masters         1
# Assoc-acdm      1
# Name: count, dtype: int64

# %%
df.loc[df['hours-per-week'] == 99, 'education'].value_counts()
# Out:
# education
# HS-grad         18
# Some-college    14
# Bachelors       10
# Doctorate        7
# Masters          7
# 7th-8th          7
# Prof-school      6
# 10th             5
# Assoc-voc        4
# Assoc-acdm       4
# 9th              1
# 11th             1
# 12th             1
# Name: count, dtype: int64

# %% [markdown]
# **What percentage of people who work the minimum hours per week have a salary of more than 50k?**

# %% [markdown]
# Hours per week and the count of people that have a salary >50k working the respective hours

# %%
df.loc[df['salary'].str.contains('>50K'), 'hours-per-week'].value_counts().head()
# Out:
# hours-per-week
# 40    3246
# 50    1276
# 45     685
# 60     648
# 55     323
# Name: count, dtype: int64

# %%
#example
df.loc[df['hours-per-week'] == 40, 'salary'].value_counts()
# Out:
# salary
# <=50K    11958
# >50K      3246
# Name: count, dtype: int64

# %% [markdown]
# Individuals that works the minimum hours per week and have a salary >50k

# %%
df.loc[df['hours-per-week'] == 1, 'salary'].value_counts()
# Out:
# salary
# <=50K    18
# >50K      2
# Name: count, dtype: int64

# %%
min_hours_mask = (df['hours-per-week'] == 1) & (df['salary'].str.contains('>50K'))
df.loc[min_hours_mask]
# Out:
#        age  workclass  fnlwgt  education  education-num      marital-status  \
# 188     58  State-gov  109567  Doctorate             16  Married-civ-spouse
# 20071   65          ?   76043    HS-grad              9  Married-civ-spouse
#
#            occupation relationship   race   sex  capital-gain  capital-loss  \
# 188    Prof-specialty      Husband  White  Male             0             0
# 20071               ?      Husband  White  Male             0             0
#
#        hours-per-week native-country salary
# 188                 1  United-States   >50K
# 20071               1  United-States   >50K

# %%
salary_ranges = df['salary'].value_counts()
salary_ranges
# Out:
# salary
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64

# %%
min_hours_percentage = (2 * 100) / 7839
f'Percentage of people that work the minimum hours and have a salary >50k: {round(min_hours_percentage, 2)}%'
# Out:
# 'Percentage of people that work the minimum hours and have a salary >50k: 0.03%'

# %% [markdown]
# **What percentage of people who works the maximum hours per week have a salary above 50k?**

# %%
df.loc[df['hours-per-week'] == 99, 'salary'].value_counts()
# Out:
# salary
# <=50K    60
# >50K     25
# Name: count, dtype: int64

# %%
max_hours_mask = (df['hours-per-week'] == 99) & (df['salary'].str.contains('>50K'))
# df.loc[max_hours_mask].shape[0]
df_max_hours = df.loc[max_hours_mask]
df_max_hours.head()
# Out:
#       age         workclass  fnlwgt     education  education-num  \
# 934    37           Private  176900       HS-grad              9
# 1171   25           Private  404616       Masters             14
# 1886   55  Self-emp-not-inc  184425  Some-college             10
# 3577   37      Self-emp-inc  382802     Doctorate             16
# 4440   43      Self-emp-inc  286750   Prof-school             15
#
#           marital-status       occupation   relationship   race   sex  \
# 934   Married-civ-spouse     Craft-repair        Husband  White  Male
# 1171  Married-civ-spouse  Farming-fishing  Not-in-family  White  Male
# 1886  Married-civ-spouse  Farming-fishing        Husband  White  Male
# 3577  Married-civ-spouse   Prof-specialty        Husband  Black  Male
# 4440  Married-civ-spouse   Prof-specialty        Husband  Black  Male
#
#       capital-gain  capital-loss  hours-per-week native-country salary
# 934              0             0              99  United-States   >50K
# ...

# %%
df_max_hours['education'].value_counts()
# Out:
# education
# Some-college    6
# HS-grad         5
# Doctorate       3
# Prof-school     3
# Bachelors       3
# Masters         2
# 7th-8th         1
# Assoc-voc       1
# Assoc-acdm      1
# Name: count, dtype: int64

# %%
max_hours_percentage = (25 * 100) / 7839
f'Percentage of individuals working the maximum hours and have a salary >50k: {round(max_hours_percentage, 2)}%'
# Out:
# 'Percentage of individuals working the maximum hours and have a salary >50k: 0.32%'

# %%
# percentage of people working 40 hours per week with a salary >50k (only for verify)
exam_percentage = (3246 * 100) / 7839
f'Percentage of individuals that works 40 hours per week and have a salary above 50k: {round(exam_percentage, 2)}%'
# Out:
# 'Percentage of individuals that works 40 hours per week and have a salary above 50k: 41.41%'

# %% [markdown]
# **What country has the highest percentage of people that earn >50k and what is that percentage?**

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df_high_salary = pd.DataFrame(df.loc[df['salary'].str.contains('>50K'), 'native-country'].value_counts()).reset_index()
df_high_salary.rename(columns={'count': 'individuals'}, inplace=True)
df_high_salary['%'] = round((df_high_salary['individuals'] / df_high_salary['individuals'].sum()) * 100, 2)
df_high_salary.head(1)
# Out:
#   native-country  individuals      %
# 0  United-States         7169  91.45

# %%
f'The country with the highest percentage of people with a salary above 50K is {df_high_salary.iloc[0, 0]}'
# Out:
# 'The country with the highest percentage of people with a salary above 50K is United-States'

# %% [markdown]
# **Identify the most popular occupation for those who earn >50k in India.**

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
popular_occupation_india = df.loc[(df['salary'].str.contains('>50K') & (df['native-country'].str.contains('India'))), 'occupation'].value_counts().idxmax()
f'The most popular occupation for those who earn >50K in India is {popular_occupation_india}.'
# Out:
# 'The most popular occupation for those who earn >50K in India is Prof-specialty.'

# %% [markdown]
# Individuals living in India

# %%
df.loc[df['native-country'] == 'India'].shape[0]
# Out:
# 100

# %% [markdown]
# Individuals living in India by range salary

# %%
df.loc[df['native-country'] == 'India', 'salary'].value_counts()
# Out:
# salary
# <=50K    60
# >50K     40
# Name: count, dtype: int64

# %%
india_high_salary_popular_occupation = df['occupation'].loc[df['native-country'].str.contains('India') & df['salary'].str.contains('>50K')].value_counts()
india_high_salary_popular_occupation.head(1)
# Out:
# occupation
# Prof-specialty    25
# Name: count, dtype: int64
